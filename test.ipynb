# %% [markdown]
# # Python spending app

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
transactions = pd.read_excel(
    "data/transactions.xls",
    skiprows= 2
)

# %%
transactions
# Out:
#     Date operation Categorie operation              Sous Categorie operation  \
# 0       02-04-2026             Revenus                         Virement reçu
# 1       02-04-2026       À catégoriser                           Chèque émis
# 2       02-04-2026              Banque                       Frais bancaires
# 3       02-04-2026     Vie Quotidienne             Alimentation, supermarché
# 4       31-03-2026  Loisirs et Sorties  Divertissements, sorties culturelles
# ..             ...                 ...                                   ...
# 506     03-03-2025             Revenus                         À catégoriser
# 507     03-03-2025             Revenus                         À catégoriser
# 508     03-03-2025             Revenus                         À catégoriser
# 509     03-03-2025             Revenus                         À catégoriser
# 510     03-03-2025             Revenus                         À catégoriser
#
#                                      Libelle operation  Montant operation  \
# 0    VIREMENT DE MME KATHERINE COUTIN  MOTIF: PAYME...              35.00
# 1                                       CHEQUE 9632276             -30.00
# 2    COMMISSIONS COTISATION A UNE OFFRE GROUPEE DE ...             -11.04
# 3    PAIEMENT CB CARREFOUR DU 31/03/26 A PARIS - CA...              -3.90
# 4    PAIEMENT CB LESPETITESFLECH DU 30/03/26 A 11 P...             -39.00
# ..                                                 ...                ...
# 506                                                NaN               0.00
# 507                                                NaN               0.00
# 508                                                NaN               0.00
# 509                                                NaN               0.00
# 510                                                NaN               0.00
#
#      Pointage operation  Commentaire operation
# 0                   NaN                    NaN
# 1                   NaN                    NaN
# 2                   NaN                    NaN
# 3                   NaN                    NaN
# 4                   NaN                    NaN
# ..                  ...                    ...
# 506                 NaN                    NaN
# 507                 NaN                    NaN
# 508                 NaN                    NaN
# 509                 NaN                    NaN
# 510                 NaN                    NaN
#
# [511 rows x 7 columns]

# %%
columns = transactions.columns.to_list()

# %%
columns
# Out:
# ['Date operation',
#  'Categorie operation',
#  'Sous Categorie operation',
#  'Libelle operation',
#  'Montant operation',
#  'Pointage operation',
#  'Commentaire operation']

# %%
col_map = {'Date operation' : 'date',
           'Categorie operation' : 'category',
           'Sous Categorie operation' : 'subcategory',
           'Libelle operation' : 'label',
           'Montant operation' : 'amount',
           'Pointage operation' : 'status',
           'Commentaire operation' : 'comment'} 

transactions = transactions.rename(columns= col_map)

transactions
# Out:
#            date            category                           subcategory  \
# 0    02-04-2026             Revenus                         Virement reçu
# 1    02-04-2026       À catégoriser                           Chèque émis
# 2    02-04-2026              Banque                       Frais bancaires
# 3    02-04-2026     Vie Quotidienne             Alimentation, supermarché
# 4    31-03-2026  Loisirs et Sorties  Divertissements, sorties culturelles
# ..          ...                 ...                                   ...
# 506  03-03-2025             Revenus                         À catégoriser
# 507  03-03-2025             Revenus                         À catégoriser
# 508  03-03-2025             Revenus                         À catégoriser
# 509  03-03-2025             Revenus                         À catégoriser
# 510  03-03-2025             Revenus                         À catégoriser
#
#                                                  label  amount  status  \
# 0    VIREMENT DE MME KATHERINE COUTIN  MOTIF: PAYME...   35.00     NaN
# 1                                       CHEQUE 9632276  -30.00     NaN
# 2    COMMISSIONS COTISATION A UNE OFFRE GROUPEE DE ...  -11.04     NaN
# 3    PAIEMENT CB CARREFOUR DU 31/03/26 A PARIS - CA...   -3.90     NaN
# 4    PAIEMENT CB LESPETITESFLECH DU 30/03/26 A 11 P...  -39.00     NaN
# ..                                                 ...     ...     ...
# 506                                                NaN    0.00     NaN
# 507                                                NaN    0.00     NaN
# 508                                                NaN    0.00     NaN
# 509                                                NaN    0.00     NaN
# 510                                                NaN    0.00     NaN
#
#      comment
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 506      NaN
# 507      NaN
# 508      NaN
# 509      NaN
# 510      NaN
#
# [511 rows x 7 columns]

# %%
transactions.columns.tolist()
# Out:
# ['date', 'category', 'subcategory', 'label', 'amount', 'status', 'comment']

# %%
transactions.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 511 entries, 0 to 510
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         511 non-null    str
#  1   category     511 non-null    str
#  2   subcategory  511 non-null    str
#  3   label        493 non-null    str
#  4   amount       511 non-null    float64
#  5   status       0 non-null      float64
#  6   comment      0 non-null      float64
# dtypes: float64(3), str(4)
# memory usage: 83.9 KB

# %%
transactions.to_csv("data/test.csv")

# %%
tester = transactions.copy()

# %%
tester['subcategory'].unique()
# Out:
# <ArrowStringArray>
# [                       'Virement reçu',
#                           'Chèque émis',
#                       'Frais bancaires',
#             'Alimentation, supermarché',
#  'Divertissements, sorties culturelles',
#                     'Restaurants, bars',
#                      'Achats, shopping',
#                         'Virement émis',
#           'Achat multimédia, high-tech',
#                               'Cadeaux',
#                             'Carburant',
#                         'Stationnement',
#                  'Transports en commun',
#                                 'Sport',
#                       'Dons caritatifs',
#                           'Chèque reçu',
#                  'Aides et allocations',
#                             'Pharmacie',
#       'Billet d'avion, billet de train',
#                'Musique, livres, films',
#       'Avocats, notaires, comptabilité',
#                         'Remboursement',
#              'Vie quotidienne - Autres',
#           'Coiffeur, cosmétique, soins',
#           'Loisirs et sorties - Autres',
#                           'Habillement',
#                   'Impôt sur le revenu',
#                       'Banque - Autres',
#                               'Épargne',
#        'Salaires et revenus d'activité',
#                'Bricolage et jardinage',
#                         'Frais postaux',
#                             'Téléphone',
#                     'Retrait d'espèces',
#                                 'Loyer',
#       'Mobilier, electroménager, déco.',
#                     'Voyages, vacances',
#                         'À catégoriser']
# Length: 38, dtype: str

# %%
def is_savings(row):
    if row['amount'] < 0 and row['category'] == 'Banque':
        return 'épargne'
    elif row['amount'] < 0 :
        return 'dépense'
    else:
        return 'revenu'
    
tester['label'] = tester.apply(is_savings, axis= 1)

# %%
tester[tester['label'] == 'épargne']
# Out:
#            date category      subcategory    label   amount  status  comment
# 2    02-04-2026   Banque  Frais bancaires  épargne   -11.04     NaN      NaN
# 44   03-03-2026   Banque  Frais bancaires  épargne   -11.04     NaN      NaN
# 83   03-02-2026   Banque  Frais bancaires  épargne   -11.04     NaN      NaN
# 116  05-01-2026   Banque  Frais bancaires  épargne   -10.43     NaN      NaN
# 143  08-12-2025   Banque  Banque - Autres  épargne  -150.00     NaN      NaN
# 158  02-12-2025   Banque  Frais bancaires  épargne   -10.43     NaN      NaN
# 159  28-11-2025   Banque  Banque - Autres  épargne  -200.00     NaN      NaN
# 173  17-11-2025   Banque  Banque - Autres  épargne  -200.00     NaN      NaN
# 194  04-11-2025   Banque  Frais bancaires  épargne   -10.43     NaN      NaN
# 204  30-10-2025   Banque          Épargne  épargne -2300.00     NaN      NaN
# 223  02-10-2025   Banque  Frais bancaires  épargne   -10.43     NaN      NaN
# 238  03-09-2025   Banque          Épargne  épargne -1670.00     NaN      NaN
# 240  02-09-2025   Banque  Frais bancaires  épargne   -10.43     NaN      NaN
# 244  29-08-2025   Banque  Frais bancaires  épargne   -24.00     NaN      NaN
# 248  18-08-2025   Banque          Épargne  épargne -6000.00     NaN      NaN
# 250  04-08-2025   Banque  Frais bancaires  épargne    -8.77     NaN      NaN
# 251  31-07-2025   Banque          Épargne  épargne   -30.00     NaN      NaN
# 280  02-07-2025   Banque  Frais bancaires  épargne    -8.77     NaN      NaN
# 354  03-06-2025   Banque  Frais bancaires  épargne    -8.77     NaN      NaN
# 392  05-05-2025   Banque  Frais bancaires  épargne    -8.77     NaN      NaN
# 411  11-04-2025   Banque  Banque - Autres  épargne  -150.00     NaN      NaN
# 416  07-04-2025   Banque  Banque - Autres  épargne  -300.00     NaN      NaN
# 427  02-04-2025   Banque  Frais bancaires  épargne    -8.77     NaN      NaN

# %%
tester = pd.read_excel("data/transactions.xls",
                       skiprows= 2
)

# renaming columns
col_map = {'Date operation' : 'date',
           'Categorie operation' : 'category',
           'Sous Categorie operation' : 'subcategory',
           'Libelle operation' : 'label',
           'Montant operation' : 'amount',
           'Pointage operation' : 'status',
           'Commentaire operation' : 'comment'} 

tester = tester.rename(columns= col_map)

# removing useless columns and NaN rows
tester = tester.drop(columns= ['status', 'comment'])
tester = tester.dropna()

tester.to_excel("data/transactions2.xlsx", index= False)

# %%
transactions = pd.read_excel("data/transactions.xlsx")

#this is our income
income = transactions[transactions['amount'] > 0]
#some of the spending is actually going towards our savings account. We don't want to count it as an expense
negative = transactions[transactions['amount'] < 0]

savings = negative[negative['subcategory'] == 'Épargne']
expense = negative[negative['subcategory'] != 'Épargne']

# %%
negative
# Out:
#            date            category                           subcategory  \
# 1    02-04-2026       À catégoriser                           Chèque émis
# 2    02-04-2026              Banque                       Frais bancaires
# 3    02-04-2026     Vie Quotidienne             Alimentation, supermarché
# 4    31-03-2026  Loisirs et Sorties  Divertissements, sorties culturelles
# 6    31-03-2026  Loisirs et Sorties                     Restaurants, bars
# ..          ...                 ...                                   ...
# 488  10-03-2025  Loisirs et Sorties                     Restaurants, bars
# 489  10-03-2025  Loisirs et Sorties                     Restaurants, bars
# 490  10-03-2025     Vie Quotidienne             Alimentation, supermarché
# 491  10-03-2025     Vie Quotidienne             Alimentation, supermarché
# 492  10-03-2025     Vie Quotidienne             Alimentation, supermarché
#
#                                                  label  amount
# 1                                       CHEQUE 9632276  -30.00
# 2    COMMISSIONS COTISATION A UNE OFFRE GROUPEE DE ...  -11.04
# 3    PAIEMENT CB CARREFOUR DU 31/03/26 A PARIS - CA...   -3.90
# 4    PAIEMENT CB LESPETITESFLECH DU 30/03/26 A 11 P...  -39.00
# 6    PAIEMENT CB SONNY S PIZZA DU 27/03/26 A PARIS ...  -35.00
# ..                                                 ...     ...
# 488  PAIEMENT CB LE LOBBY BAR DU 07/03/25 A LILLE -...  -12.00
# 489  PAIEMENT CB PHOENICIA DU 09/03/25 A LILLE - CA...   -9.50
# 490  PAIEMENT CB LA GOURMANDISE DU 07/03/25 A LILLE...   -5.00
# 491  PAIEMENT CB MAXICOFFEE NORD DU 07/03/25 A NEUV...   -0.70
# 492  PAIEMENT CB LA GOURMANDISE DU 07/03/25 A LILLE...   -0.30
#
# [418 rows x 5 columns]

# %%
expense = negative[negative['subcategory'] != 'Épargne']

expense[expense['category'] == 'À catégoriser']
# Out:
#            date       category        subcategory  \
# 1    02-04-2026  À catégoriser        Chèque émis
# 9    30-03-2026  À catégoriser      Virement émis
# 13   26-03-2026  À catégoriser      Virement émis
# 27   16-03-2026  À catégoriser      Virement émis
# 131  23-12-2025  À catégoriser      Virement émis
# 195  03-11-2025  À catégoriser      Virement émis
# 201  31-10-2025  À catégoriser      Virement émis
# 230  22-09-2025  À catégoriser      Virement émis
# 232  22-09-2025  À catégoriser      Virement émis
# 246  25-08-2025  À catégoriser  Retrait d'espèces
# 265  16-07-2025  À catégoriser      Virement émis
# 329  16-06-2025  À catégoriser      Virement émis
# 360  28-05-2025  À catégoriser      Virement émis
# 396  28-04-2025  À catégoriser      Virement émis
# 397  28-04-2025  À catégoriser      Virement émis
# 405  23-04-2025  À catégoriser      Virement émis
# 451  24-03-2025  À catégoriser      Virement émis
# 483  10-03-2025  À catégoriser  Retrait d'espèces
#
#                                                  label   amount
# 1                                       CHEQUE 9632276   -30.00
# 9    VIREMENT INSTANTANE EMIS VERS DOUGLAS EUGENE P...  -240.00
# 13   VIREMENT INSTANTANE EMIS VERS HELOISE RIVAL - ...  -130.00
# 27   VIREMENT INSTANTANE EMIS VERS KATHERINE C - MO...   -15.00
# 131  VIREMENT INSTANTANE EMIS VERS JULIA-MARIE P - ...   -50.00
# 195  VIREMENT VERS MR PENNER-LACOMPTE DOUGLAS - MOT... -1000.00
# 201  VIREMENT VERS MR PENNER-LACOMPTE DOUGLAS - MOT... -2000.00
# 230  VIREMENT INSTANTANE EMIS VERS DOUGLAS PENNER -... -1000.00
# 232  VIREMENT INSTANTANE EMIS VERS DOUGLAS PENNER -...   -50.00
# 246  RETRAIT DISTRIBUTEUR BNP PARIBAS DU 24/08/25 1...   -20.00
# 265  VIREMENT INSTANTANE EMIS VERS COME LHUSSIER - ...  -170.00
# 329  VIREMENT INSTANTANE EMIS VERS JULIA-MARIE P - ...  -110.00
# 360  VIREMENT VERS MR PENNER-LACOMPTE DOUGLAS - MOT...   -36.00
# 396  VIREMENT ETRANGER /BEN 1/DYLAN RIGAL/BIC HBUKG...   -35.64
# 397  VIREMENT INSTANTANE EMIS VERS KEVIN RIZZOTTO -...   -15.00
# 405  VIREMENT INSTANTANE EMIS VERS MARINA F - MOTIF...   -11.00
# 451  VIREMENT VERS MR PENNER-LACOMPTE DOUGLAS - MOT...   -20.00
# 483  RETRAIT DISTRIBUTEUR CAISSE D EPARGNE HAU DU 0...   -40.00

# %%
expense['abs_amount'] = expense['abs_amount'].abs()
chart_expense_df = expense.groupby('category')['abs_amount'].sum().reset_index()

chart_expense_df
# Out:
#                     category  abs_amount
# 0  Abonnements et Telephonie       17.95
# 1            Autres Dépenses     1099.00
# 2                     Banque     1153.12
# 3            Impôts et Taxes      304.00
# 4                   Logement     2647.11
# 5         Loisirs et Sorties     2357.12
# 6                      Santé      126.91
# 7    Transports et Véhicules     1953.29
# 8            Vie Quotidienne     3833.26
# 9              À catégoriser     4972.64

# %%
fig = px.pie(chart_expense_df, values= 'amount', names= 'category', title= 'Spending repartition')
fig.show()
